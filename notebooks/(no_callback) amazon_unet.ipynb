# %%
# importing the libraries
import os
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import Sequence, to_categorical
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from IPython.display import clear_output

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/Shareddrives/ShupponKu/amazon_dataset/'

# %%
train_folder= os.path.join(data_dir,'training')
valid_folder= os.path.join(data_dir,'validation')
sample_folder= os.path.join(data_dir,'sample')
test_folder= os.path.join(data_dir,'sample')
num_of_training_img = len(os.listdir(train_folder + '/images')) 
num_of_training_mask = len(os.listdir(train_folder + '/masks'))
num_of_val_img = len(os.listdir(valid_folder + '/images'))
num_of_test_img = len(os.listdir(test_folder + '/images'))

# %%
print(f"There are {num_of_training_img} images.\n")
print(f"There are {num_of_training_mask} masks.\n")
# Out:
# There are 30 images.
#
# There are 30 masks.

# %% [markdown]
# --BATAS SUCI--

# %%
train_dir=train_folder
val_dir=valid_folder
test_dir=test_folder
sample_dir = sample_folder

# %%
img_dim = 512
BATCH_SIZE = 1 
seed = 42

# %%
from PIL import Image
import random
import seaborn as sns

# %%
tr_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    horizontal_flip=True,
    vertical_flip=True,
)

val_datagen = ImageDataGenerator(
    rescale=1./255
)

train_image_generator = tr_datagen.flow_from_directory(
        train_dir,
        classes=['images'],
        shuffle=False,
        target_size=(img_dim, img_dim),
        seed=seed,
        class_mode = None,
        batch_size = BATCH_SIZE,
)
    
train_mask_generator = tr_datagen.flow_from_directory(
        train_dir,
        classes=['masks'],
        shuffle=False,
        target_size=(img_dim, img_dim),
        seed=seed,
        class_mode = None,
        color_mode='grayscale',
        batch_size = BATCH_SIZE,
)

val_image_generator = val_datagen.flow_from_directory(
        val_dir,
        classes=['images'],
        shuffle=False,
        target_size=(img_dim, img_dim),
        seed=seed,
        class_mode = None,
        batch_size = BATCH_SIZE,

)
    
val_mask_generator = val_datagen.flow_from_directory(
        val_dir,
        classes=['masks'],
        shuffle=False,
        target_size=(img_dim, img_dim),
        seed=seed,
        class_mode = None,
        color_mode='grayscale',
        batch_size = BATCH_SIZE,
)
test_image_generator = val_datagen.flow_from_directory(
        test_dir,
        classes=['images'],
        shuffle=False,
        target_size=(img_dim, img_dim),
        seed=seed,
        class_mode = None,
        batch_size = BATCH_SIZE,

)
    
test_mask_generator = val_datagen.flow_from_directory(
        test_dir,
        classes=['masks'],
        shuffle=False,
        target_size=(img_dim, img_dim),
        seed=seed,
        class_mode = None,
        color_mode='grayscale',
        batch_size = BATCH_SIZE,
)
sam_image_generator = val_datagen.flow_from_directory(
        sample_folder,
        classes=['images'],
        shuffle=False,
        target_size=(img_dim, img_dim),
        seed=seed,
        class_mode = None,
        batch_size = BATCH_SIZE,

)
    
sam_mask_generator = val_datagen.flow_from_directory(
        sample_folder,
        classes=['masks'],
        shuffle=False,
        target_size=(img_dim, img_dim),
        seed=seed,
        class_mode = None,
        color_mode='grayscale',
        batch_size = BATCH_SIZE,
)

train_generator = zip(train_image_generator, train_mask_generator)
val_generator = zip(val_image_generator, val_mask_generator)
test_generator = zip(test_image_generator, test_mask_generator)
sample_generator = zip(sam_image_generator, sam_mask_generator)
# Out:
# Found 30 images belonging to 1 classes.
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py:193: UserWarning: Using ".tiff" files with multiple bands will cause distortion. Please verify your output.
#   warnings.warn('Using ".tiff" files with multiple bands '
# Found 30 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 15 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.

# %%
# helper function to display an image, it's label and the prediction
def display(display_list):
    plt.figure(figsize=(10, 10))
    title = ['Input Image', 'Label', 'Predicted Label']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.utils.array_to_img(display_list[i]), cmap='gray')
        plt.axis('off')
    plt.show()

# %%
num_sample = 1
n = 0
# print(train_image_generator.shape)
for image, mask in sample_generator:
    sample_image, sample_label = image[0], mask[0]
    if n < num_sample:
        display([sample_image, sample_label])
        n+=1
    else:
        break

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.applications.vgg16 import *

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, activation='elu', kernel_initializer='he_normal', padding="same")(input)
    x = Dropout(0.1)(x)    
    x = Conv2D(num_filters, 3, activation='elu', kernel_initializer='he_normal', padding="same")(x)
    return x

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 16)
    s2, p2 = encoder_block(p1, 32)
    s3, p3 = encoder_block(p2, 64)
    s4, p4 = encoder_block(p3, 128)

    b1 = conv_block(p4, 256)

    d1 = decoder_block(b1, s4, 128)
    d2 = decoder_block(d1, s3, 64)
    d3 = decoder_block(d2, s2, 32)
    d4 = decoder_block(d3, s1, 16)

    outputs = Conv2D(1, 1, activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
from keras import backend as K

def dice_coef(y_true, y_pred):
    intersect = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    fsum = K.sum(y_true,[1,2,3])
    ssum = K.sum(y_pred,[1,2,3])
    dice = (2 * intersect ) / (fsum + ssum)
    dice = K.mean(dice)
    return dice  

def iou_coef(y_true, y_pred, smooth=0.0001):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# %%
# defining the tensorflow distribute strategy
# strategy = tf.distribute.MirroredStrategy()

# %%
# # calling the model inside the scope
# with strategy.scope():
model = build_unet((img_dim, img_dim, 3))
# compiling the model with the optimizer, loss function and acc metrics
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt,
            loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[iou_coef,dice_coef,'accuracy', 'mse'])

# %%
# let's see how our FCN implemented model looks like
# does it looks like the architecture fig above?
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# function to show the prediction
def show_predictions(dataset=None, num=1):
  if dataset:
    n = 0
    for image, mask in dataset:
      image, mask = image, mask
      if n < num:
        pred_mask = model.predict(image)
        print(f'image shape {image.shape}')
        print(f'mask shape {mask.shape}')
        print(f'pred_mask shape {pred_mask.shape}')
        display([image[0], mask[0],pred_mask[0]])
        n+=1
      else:
        break
  else:
    prediction = model.predict(sample_image[tf.newaxis, ...])
    display([sample_image, sample_label, prediction[0]])

# %%
# # Let's see a sample of input image it's true mask and what our model is predicted given the input image
show_predictions(test_generator)
# Out:
# 1/1 [==============================] - 9s 9s/step
# image shape (1, 512, 512, 3)
# mask shape (1, 512, 512, 1)
# pred_mask shape (1, 512, 512, 1)

# %%
# calllback to displaying the predictions of our model while training
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    show_predictions()
    print ('\nSample Prediction after epoch {}\n'.format(epoch+1))
   
 # ReduceLROnPlateau callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.00001)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta = 0, patience = 5, verbose = 1)

# %%
# defining some hyperparameters
TRAIN_LENGTH = 257
#128
STEPS_PER_EPOCH = 100

EPOCHS = 50
VAL_SUBSPLITS = 5
TEST_SIZE=15
VALIDATION_STEPS = TEST_SIZE//BATCH_SIZE#//VAL_SUBSPLITS

model_history = model.fit(train_generator, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=val_generator,
                          callbacks=[reduce_lr]
                          )
# Out:
# Epoch 1/50
# 100/100 [==============================] - 100s 980ms/step - loss: 0.5168 - iou_coef: 0.4482 - dice_coef: 0.5903 - accuracy: 0.7174 - mse: 0.1686 - val_loss: 0.4730 - val_iou_coef: 0.5861 - val_dice_coef: 0.7009 - val_accuracy: 0.7901 - val_mse: 0.1562 - lr: 1.0000e-04
# Epoch 2/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.2739 - iou_coef: 0.6425 - dice_coef: 0.7495 - accuracy: 0.8793 - mse: 0.0743 - val_loss: 0.4129 - val_iou_coef: 0.6537 - val_dice_coef: 0.7547 - val_accuracy: 0.8400 - val_mse: 0.1254 - lr: 1.0000e-04
# Epoch 3/50
# 100/100 [==============================] - 11s 107ms/step - loss: 0.2478 - iou_coef: 0.6627 - dice_coef: 0.7598 - accuracy: 0.8913 - mse: 0.0650 - val_loss: 0.3821 - val_iou_coef: 0.6664 - val_dice_coef: 0.7659 - val_accuracy: 0.8580 - val_mse: 0.1121 - lr: 1.0000e-04
# Epoch 4/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2152 - iou_coef: 0.7015 - dice_coef: 0.7958 - accuracy: 0.9018 - mse: 0.0562 - val_loss: 0.2421 - val_iou_coef: 0.6734 - val_dice_coef: 0.7705 - val_accuracy: 0.9052 - val_mse: 0.0718 - lr: 1.0000e-04
# Epoch 5/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2126 - iou_coef: 0.7079 - dice_coef: 0.8001 - accuracy: 0.9011 - mse: 0.0560 - val_loss: 0.2395 - val_iou_coef: 0.6853 - val_dice_coef: 0.7824 - val_accuracy: 0.9059 - val_mse: 0.0708 - lr: 1.0000e-04
# Epoch 6/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2116 - iou_coef: 0.6983 - dice_coef: 0.7892 - accuracy: 0.9032 - mse: 0.0547 - val_loss: 0.3226 - val_iou_coef: 0.6988 - val_dice_coef: 0.7950 - val_accuracy: 0.8812 - val_mse: 0.0923 - lr: 1.0000e-04
# Epoch 7/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1910 - iou_coef: 0.7221 - dice_coef: 0.8097 - accuracy: 0.9092 - mse: 0.0496 - val_loss: 0.2235 - val_iou_coef: 0.6931 - val_dice_coef: 0.7890 - val_accuracy: 0.9150 - val_mse: 0.0649 - lr: 1.0000e-04
# Epoch 8/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1974 - iou_coef: 0.7207 - dice_coef: 0.8075 - accuracy: 0.9053 - mse: 0.0523 - val_loss: 0.2202 - val_iou_coef: 0.6992 - val_dice_coef: 0.7967 - val_accuracy: 0.9161 - val_mse: 0.0639 - lr: 1.0000e-04
# Epoch 9/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2043 - iou_coef: 0.7135 - dice_coef: 0.8005 - accuracy: 0.9060 - mse: 0.0521 - val_loss: 0.3218 - val_iou_coef: 0.7111 - val_dice_coef: 0.8056 - val_accuracy: 0.8868 - val_mse: 0.0884 - lr: 1.0000e-04
# Epoch 10/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.1822 - iou_coef: 0.7384 - dice_coef: 0.8238 - accuracy: 0.9119 - mse: 0.0470 - val_loss: 0.2386 - val_iou_coef: 0.7154 - val_dice_coef: 0.8083 - val_accuracy: 0.9110 - val_mse: 0.0678 - lr: 1.0000e-04
# Epoch 11/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.1973 - iou_coef: 0.7242 - dice_coef: 0.8116 - accuracy: 0.9039 - mse: 0.0521 - val_loss: 0.2161 - val_iou_coef: 0.6573 - val_dice_coef: 0.7630 - val_accuracy: 0.9163 - val_mse: 0.0636 - lr: 1.0000e-04
# Epoch 12/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1936 - iou_coef: 0.7183 - dice_coef: 0.8051 - accuracy: 0.9095 - mse: 0.0489 - val_loss: 0.2626 - val_iou_coef: 0.7228 - val_dice_coef: 0.8161 - val_accuracy: 0.9029 - val_mse: 0.0741 - lr: 1.0000e-04
# Epoch 13/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1809 - iou_coef: 0.7367 - dice_coef: 0.8231 - accuracy: 0.9109 - mse: 0.0471 - val_loss: 0.2747 - val_iou_coef: 0.7259 - val_dice_coef: 0.8164 - val_accuracy: 0.9024 - val_mse: 0.0757 - lr: 1.0000e-04
# Epoch 14/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.1933 - iou_coef: 0.7358 - dice_coef: 0.8225 - accuracy: 0.9089 - mse: 0.0493 - val_loss: 0.1981 - val_iou_coef: 0.7018 - val_dice_coef: 0.7966 - val_accuracy: 0.9232 - val_mse: 0.0577 - lr: 1.0000e-04
# Epoch 15/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1898 - iou_coef: 0.7285 - dice_coef: 0.8121 - accuracy: 0.9134 - mse: 0.0461 - val_loss: 0.2143 - val_iou_coef: 0.7352 - val_dice_coef: 0.8274 - val_accuracy: 0.9201 - val_mse: 0.0609 - lr: 1.0000e-04
# Epoch 16/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1699 - iou_coef: 0.7508 - dice_coef: 0.8334 - accuracy: 0.9153 - mse: 0.0434 - val_loss: 0.2031 - val_iou_coef: 0.7332 - val_dice_coef: 0.8233 - val_accuracy: 0.9242 - val_mse: 0.0576 - lr: 1.0000e-04
# Epoch 17/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1779 - iou_coef: 0.7430 - dice_coef: 0.8252 - accuracy: 0.9143 - mse: 0.0450 - val_loss: 0.1921 - val_iou_coef: 0.7161 - val_dice_coef: 0.8064 - val_accuracy: 0.9259 - val_mse: 0.0557 - lr: 1.0000e-04
# Epoch 18/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1786 - iou_coef: 0.7425 - dice_coef: 0.8224 - accuracy: 0.9206 - mse: 0.0417 - val_loss: 0.1949 - val_iou_coef: 0.7352 - val_dice_coef: 0.8251 - val_accuracy: 0.9267 - val_mse: 0.0553 - lr: 1.0000e-04
# Epoch 19/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1629 - iou_coef: 0.7567 - dice_coef: 0.8374 - accuracy: 0.9200 - mse: 0.0408 - val_loss: 0.1794 - val_iou_coef: 0.7399 - val_dice_coef: 0.8297 - val_accuracy: 0.9286 - val_mse: 0.0531 - lr: 1.0000e-04
# Epoch 20/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1722 - iou_coef: 0.7531 - dice_coef: 0.8326 - accuracy: 0.9160 - mse: 0.0433 - val_loss: 0.1809 - val_iou_coef: 0.7276 - val_dice_coef: 0.8161 - val_accuracy: 0.9307 - val_mse: 0.0520 - lr: 1.0000e-04
# Epoch 21/50
# 100/100 [==============================] - 11s 108ms/step - loss: 0.1761 - iou_coef: 0.7406 - dice_coef: 0.8206 - accuracy: 0.9186 - mse: 0.0423 - val_loss: 0.1709 - val_iou_coef: 0.7359 - val_dice_coef: 0.8277 - val_accuracy: 0.9326 - val_mse: 0.0496 - lr: 1.0000e-04
# Epoch 22/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1566 - iou_coef: 0.7714 - dice_coef: 0.8486 - accuracy: 0.9218 - mse: 0.0390 - val_loss: 0.1837 - val_iou_coef: 0.7456 - val_dice_coef: 0.8336 - val_accuracy: 0.9318 - val_mse: 0.0515 - lr: 1.0000e-04
# Epoch 23/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.1609 - iou_coef: 0.7584 - dice_coef: 0.8353 - accuracy: 0.9205 - mse: 0.0399 - val_loss: 0.1669 - val_iou_coef: 0.7273 - val_dice_coef: 0.8191 - val_accuracy: 0.9354 - val_mse: 0.0480 - lr: 1.0000e-04
# Epoch 24/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1688 - iou_coef: 0.7518 - dice_coef: 0.8290 - accuracy: 0.9215 - mse: 0.0394 - val_loss: 0.1745 - val_iou_coef: 0.7372 - val_dice_coef: 0.8272 - val_accuracy: 0.9331 - val_mse: 0.0500 - lr: 1.0000e-04
# Epoch 25/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1445 - iou_coef: 0.7769 - dice_coef: 0.8512 - accuracy: 0.9247 - mse: 0.0362 - val_loss: 0.1996 - val_iou_coef: 0.7442 - val_dice_coef: 0.8334 - val_accuracy: 0.9300 - val_mse: 0.0539 - lr: 1.0000e-04
# Epoch 26/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1678 - iou_coef: 0.7606 - dice_coef: 0.8395 - accuracy: 0.9177 - mse: 0.0420 - val_loss: 0.1701 - val_iou_coef: 0.7248 - val_dice_coef: 0.8165 - val_accuracy: 0.9349 - val_mse: 0.0487 - lr: 1.0000e-04
# Epoch 27/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1682 - iou_coef: 0.7568 - dice_coef: 0.8334 - accuracy: 0.9206 - mse: 0.0401 - val_loss: 0.2004 - val_iou_coef: 0.7541 - val_dice_coef: 0.8426 - val_accuracy: 0.9343 - val_mse: 0.0519 - lr: 1.0000e-04
# Epoch 28/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1458 - iou_coef: 0.7770 - dice_coef: 0.8523 - accuracy: 0.9238 - mse: 0.0368 - val_loss: 0.1877 - val_iou_coef: 0.7528 - val_dice_coef: 0.8392 - val_accuracy: 0.9352 - val_mse: 0.0501 - lr: 1.0000e-04
# Epoch 29/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1419 - iou_coef: 0.7793 - dice_coef: 0.8516 - accuracy: 0.9253 - mse: 0.0358 - val_loss: 0.1992 - val_iou_coef: 0.7414 - val_dice_coef: 0.8283 - val_accuracy: 0.9316 - val_mse: 0.0528 - lr: 2.0000e-05
# Epoch 30/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1248 - iou_coef: 0.7859 - dice_coef: 0.8556 - accuracy: 0.9318 - mse: 0.0310 - val_loss: 0.2080 - val_iou_coef: 0.7447 - val_dice_coef: 0.8309 - val_accuracy: 0.9306 - val_mse: 0.0540 - lr: 2.0000e-05
# Epoch 31/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1196 - iou_coef: 0.7952 - dice_coef: 0.8649 - accuracy: 0.9345 - mse: 0.0291 - val_loss: 0.1910 - val_iou_coef: 0.7501 - val_dice_coef: 0.8355 - val_accuracy: 0.9343 - val_mse: 0.0507 - lr: 2.0000e-05
# Epoch 32/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1335 - iou_coef: 0.7844 - dice_coef: 0.8555 - accuracy: 0.9295 - mse: 0.0331 - val_loss: 0.2060 - val_iou_coef: 0.7453 - val_dice_coef: 0.8315 - val_accuracy: 0.9306 - val_mse: 0.0539 - lr: 2.0000e-05
# Epoch 33/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1430 - iou_coef: 0.7759 - dice_coef: 0.8472 - accuracy: 0.9297 - mse: 0.0339 - val_loss: 0.1888 - val_iou_coef: 0.7308 - val_dice_coef: 0.8201 - val_accuracy: 0.9306 - val_mse: 0.0528 - lr: 2.0000e-05
# Epoch 34/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1241 - iou_coef: 0.7956 - dice_coef: 0.8650 - accuracy: 0.9335 - mse: 0.0299 - val_loss: 0.2019 - val_iou_coef: 0.7411 - val_dice_coef: 0.8281 - val_accuracy: 0.9295 - val_mse: 0.0543 - lr: 1.0000e-05
# Epoch 35/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1337 - iou_coef: 0.7856 - dice_coef: 0.8562 - accuracy: 0.9291 - mse: 0.0326 - val_loss: 0.2045 - val_iou_coef: 0.7389 - val_dice_coef: 0.8258 - val_accuracy: 0.9289 - val_mse: 0.0548 - lr: 1.0000e-05
# Epoch 36/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1361 - iou_coef: 0.7785 - dice_coef: 0.8482 - accuracy: 0.9318 - mse: 0.0318 - val_loss: 0.2015 - val_iou_coef: 0.7420 - val_dice_coef: 0.8287 - val_accuracy: 0.9299 - val_mse: 0.0540 - lr: 1.0000e-05
# Epoch 37/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1170 - iou_coef: 0.8010 - dice_coef: 0.8688 - accuracy: 0.9365 - mse: 0.0279 - val_loss: 0.2137 - val_iou_coef: 0.7414 - val_dice_coef: 0.8272 - val_accuracy: 0.9276 - val_mse: 0.0564 - lr: 1.0000e-05
# Epoch 38/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1252 - iou_coef: 0.7898 - dice_coef: 0.8596 - accuracy: 0.9327 - mse: 0.0307 - val_loss: 0.2034 - val_iou_coef: 0.7393 - val_dice_coef: 0.8252 - val_accuracy: 0.9291 - val_mse: 0.0547 - lr: 1.0000e-05
# Epoch 39/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.1327 - iou_coef: 0.7863 - dice_coef: 0.8545 - accuracy: 0.9331 - mse: 0.0311 - val_loss: 0.2037 - val_iou_coef: 0.7415 - val_dice_coef: 0.8276 - val_accuracy: 0.9293 - val_mse: 0.0545 - lr: 1.0000e-05
# Epoch 40/50
# 100/100 [==============================] - 10s 97ms/step - loss: 0.1125 - iou_coef: 0.7997 - dice_coef: 0.8675 - accuracy: 0.9373 - mse: 0.0271 - val_loss: 0.2066 - val_iou_coef: 0.7412 - val_dice_coef: 0.8270 - val_accuracy: 0.9287 - val_mse: 0.0551 - lr: 1.0000e-05
# Epoch 41/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.1240 - iou_coef: 0.7905 - dice_coef: 0.8602 - accuracy: 0.9338 - mse: 0.0296 - val_loss: 0.2172 - val_iou_coef: 0.7329 - val_dice_coef: 0.8190 - val_accuracy: 0.9255 - val_mse: 0.0579 - lr: 1.0000e-05
# Epoch 42/50
# 100/100 [==============================] - 9s 96ms/step - loss: 0.1346 - iou_coef: 0.7844 - dice_coef: 0.8534 - accuracy: 0.9332 - mse: 0.0314 - val_loss: 0.1936 - val_iou_coef: 0.7443 - val_dice_coef: 0.8316 - val_accuracy: 0.9316 - val_mse: 0.0522 - lr: 1.0000e-05
# Epoch 43/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1209 - iou_coef: 0.7964 - dice_coef: 0.8656 - accuracy: 0.9345 - mse: 0.0290 - val_loss: 0.2131 - val_iou_coef: 0.7348 - val_dice_coef: 0.8215 - val_accuracy: 0.9265 - val_mse: 0.0569 - lr: 1.0000e-05
# Epoch 44/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1267 - iou_coef: 0.7872 - dice_coef: 0.8575 - accuracy: 0.9324 - mse: 0.0309 - val_loss: 0.2231 - val_iou_coef: 0.7336 - val_dice_coef: 0.8197 - val_accuracy: 0.9246 - val_mse: 0.0589 - lr: 1.0000e-05
# Epoch 45/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1101 - iou_coef: 0.7927 - dice_coef: 0.8604 - accuracy: 0.9377 - mse: 0.0263 - val_loss: 0.2176 - val_iou_coef: 0.7352 - val_dice_coef: 0.8209 - val_accuracy: 0.9259 - val_mse: 0.0577 - lr: 1.0000e-05
# Epoch 46/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1150 - iou_coef: 0.8053 - dice_coef: 0.8720 - accuracy: 0.9376 - mse: 0.0274 - val_loss: 0.2263 - val_iou_coef: 0.7351 - val_dice_coef: 0.8202 - val_accuracy: 0.9246 - val_mse: 0.0593 - lr: 1.0000e-05
# Epoch 47/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1193 - iou_coef: 0.7962 - dice_coef: 0.8644 - accuracy: 0.9346 - mse: 0.0289 - val_loss: 0.2282 - val_iou_coef: 0.7287 - val_dice_coef: 0.8137 - val_accuracy: 0.9234 - val_mse: 0.0601 - lr: 1.0000e-05
# Epoch 48/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1298 - iou_coef: 0.7854 - dice_coef: 0.8537 - accuracy: 0.9336 - mse: 0.0304 - val_loss: 0.1987 - val_iou_coef: 0.7450 - val_dice_coef: 0.8313 - val_accuracy: 0.9308 - val_mse: 0.0533 - lr: 1.0000e-05
# Epoch 49/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1138 - iou_coef: 0.8022 - dice_coef: 0.8701 - accuracy: 0.9375 - mse: 0.0271 - val_loss: 0.2170 - val_iou_coef: 0.7399 - val_dice_coef: 0.8250 - val_accuracy: 0.9268 - val_mse: 0.0572 - lr: 1.0000e-05
# Epoch 50/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.1270 - iou_coef: 0.7940 - dice_coef: 0.8629 - accuracy: 0.9335 - mse: 0.0302 - val_loss: 0.2003 - val_iou_coef: 0.7378 - val_dice_coef: 0.8233 - val_accuracy: 0.9291 - val_mse: 0.0547 - lr: 1.0000e-05

# %%
model.evaluate(val_generator, steps=15)
# Out:
# 15/15 [==============================] - 0s 18ms/step - loss: 0.2003 - iou_coef: 0.7378 - dice_coef: 0.8233 - accuracy: 0.9291 - mse: 0.0547
# [0.20034553110599518,
#  0.7377828359603882,
#  0.8233060836791992,
#  0.9290687441825867,
#  0.0546768382191658]

# %%
model.evaluate(val_generator, steps=num_of_test_img)
# Out:
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2703 - iou_coef: 0.8232 - dice_coef: 0.9030 - accuracy: 0.9105 - mse: 0.0719
# [0.2703416347503662,
#  0.823157548904419,
#  0.9030020833015442,
#  0.9104843139648438,
#  0.07191786170005798]

# %%
show_predictions(sample_generator)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# image shape (1, 512, 512, 3)
# mask shape (1, 512, 512, 1)
# pred_mask shape (1, 512, 512, 1)

# %%
show_predictions(val_generator, 5)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# image shape (1, 512, 512, 3)
# mask shape (1, 512, 512, 1)
# pred_mask shape (1, 512, 512, 1)
# 1/1 [==============================] - 0s 21ms/step
# image shape (1, 512, 512, 3)
# mask shape (1, 512, 512, 1)
# pred_mask shape (1, 512, 512, 1)
# 1/1 [==============================] - 0s 21ms/step
# image shape (1, 512, 512, 3)
# mask shape (1, 512, 512, 1)
# pred_mask shape (1, 512, 512, 1)
# 1/1 [==============================] - 0s 18ms/step
# image shape (1, 512, 512, 3)
# mask shape (1, 512, 512, 1)
# pred_mask shape (1, 512, 512, 1)
# 1/1 [==============================] - 0s 18ms/step
# image shape (1, 512, 512, 3)
# mask shape (1, 512, 512, 1)
# pred_mask shape (1, 512, 512, 1)

# %%
#dice
plt.plot(model_history.history['dice_coef'])
plt.plot(model_history.history['val_dice_coef'])
plt.title('model dice')
plt.ylabel('dice')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
#iou
plt.plot(model_history.history['iou_coef'])
plt.plot(model_history.history['val_iou_coef'])
plt.title('model iou')
plt.ylabel('iou')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
#accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model acc')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save('unet-c1-iou-norm.h5')
